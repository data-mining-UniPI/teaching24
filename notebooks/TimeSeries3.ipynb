# %% [markdown]
# # Time series: motif and shaplet

# %% [markdown]
# Motif: a repeated pattern in the time series.
# We can discover motif by computing the Matrix Profile: a data structure that annotates time series by using a sliding window to compare the pairwise distance among the subsequences.

# %% [markdown]
# ### Matrix Profile
# You can use these packages:
#
#
# https://github.com/target/matrixprofile-ts
#
# https://github.com/TDAmeritrade/stumpy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matrixprofile import *

# %%
df = pd.read_csv('./../data/AirPassengers.csv', parse_dates=True, index_col='Month', date_format='%Y-%m')
df.head()
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
ts = df['#Passengers']
plt.plot(ts)
plt.show()

# %%
w = 12
mp, mpi = matrixProfile.stomp(ts.values, w)

plt.plot(mp)
plt.show()

# %%
w = 3
mp, mpi = matrixProfile.stomp(ts.values, w)

plt.plot(mp)
plt.show()

# %% [markdown]
# ### Motif discovery
# Parameters
# - max_motifs: stop finding new motifs once we have max_motifs
# - radius: For each motif found, find neighbors that are within radius*motif_mp of the first.
# - n_neighbors: number of neighbors from the first to find. If it is None, find all.
# - ex_zone: minimum distance between indices for after each subsequence is identified. Defaults to m/2 where m is the subsequence length. If ex_zone = 0, only the found index is exclude, if ex_zone = 1 then if idx is found as a motif idx-1, idx, idx+1 are excluded.
#
#
# The function returns a tuple (top_motifs, distances) which are lists of the same length.
#
# - top_motifs: This is a list of the indices found for each motif. The first index is the nth motif followed by all nearest neighbors found sorted by distances.
# - distances: Minimum Matrix profile value for each motif set.

# %%
mo, mod  = motifs.motifs(ts.values, (mp, mpi), max_motifs=5)

# %%
plt.plot(ts.values)
colors = ['r', 'g', 'k', 'b', 'y'][:len(mo)]
for m, d, c in zip(mo, mod, colors):
    for i in m:
        m_shape = ts.values[i:i+w]
        plt.plot(range(i,i+w), m_shape, color=c, lw=3)

plt.show()

# %%
for m, d, c in zip(mo, mod, colors):
    for i in m:
        m_shape = ts.values[i:i+w]
        plt.plot(range(i,i+w), m_shape, color=c, lw=3)
    plt.show()

# %% [markdown]
# ### Anomaly Discovery
# Parameters
# - mp: matrix profile numpy array
# - k: the number of discords to discover
# - ex_zone: the number of samples to exclude and set to Inf on either side of a found discord
#
#
# Returns a list of indexes represent the discord starting locations. MaxInt indicates there were no more discords that could be found due to too many exclusions or profile being too small. Discord start indices are sorted by highest matrix profile value.

# %%
from matrixprofile.discords import discords
anoms = discords(mp, ex_zone=3, k=5)

# %%
plt.plot(ts.values)
colors = ['r', 'g', 'k', 'b', 'y'][:len(mo)]
for a, c in zip(anoms, colors):
    a_shape = ts.values[a:a+w]
    plt.plot(range(a, a+w), a_shape, color=c, lw=3)

plt.show()

# %% [markdown]
# ### Shaplet discovery

# %%
from pyts.datasets import make_cylinder_bell_funnel

X, y = make_cylinder_bell_funnel(n_samples=12, random_state=42)

plt.figure()
for i, classe in enumerate(['cylinder', 'bell', 'funnel']):
    plt.subplot(3, 1, i + 1)
    for x in X[y == i]:
        plt.plot(x, color='C0', linewidth=0.9)
    plt.title('Class: {}'.format(classe), fontsize=16)

plt.tight_layout()
plt.subplots_adjust(hspace=0.6)
plt.show()

# %%
from tensorflow.keras.optimizers import Adagrad
from tslearn.shapelets import ShapeletModel
from tslearn.shapelets import grabocka_params_to_shapelet_size_dict

from tslearn.preprocessing import TimeSeriesScalerMinMax

# %%
# Compute number and length of shapelets.
# l: Fraction of the length of time series to be used for base shapelet length
# r: Number of different shapelet lengths to use

# return: Dictionary giving, for each shapelet length, the number of such shapelets to be generated

# %%
n_ts, ts_sz = X.shape
n_classes = len(set(y))


shapelet_sizes = grabocka_params_to_shapelet_size_dict(n_ts=n_ts,
                                                       ts_sz=ts_sz,
                                                       n_classes=n_classes,
                                                       l=0.1,
                                                       r=1)

print('n_ts', n_ts)
print('ts_sz', ts_sz)
print('n_classes', n_classes)
print('shapelet_sizes', shapelet_sizes)
# Out:
# n_ts 12
# ts_sz 128
# n_classes 3
# shapelet_sizes {12: 3}

# %%
shp_clf = ShapeletModel(n_shapelets_per_size=shapelet_sizes,
                        optimizer="sgd",
                        weight_regularizer=.01,
                        max_iter=200,
                        verbose=1)
# Out:
# /Users/lorenzomannocci/anaconda3/envs/phd/lib/python3.12/site-packages/tslearn/shapelets/shapelets.py:354: FutureWarning: The default value for 'scale' is set to False in version 0.4 to ensure backward compatibility, but is likely to change in a future version.
#   warnings.warn("The default value for 'scale' is set to False "

# %%
shp_clf.fit(X, y)
# Out:
# Epoch 1/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 2.7670 - loss: 2.7915
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 2.5649 - loss: 2.5890
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 2.4131 - loss: 2.4368
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 2.3072 - loss: 2.3306
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 2.2328 - loss: 2.2559
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 2.1733 - loss: 2.1960
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 2.1245 - loss: 2.1469
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 2.0742 - loss: 2.0963
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 1.9603 - loss: 1.9821
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 1.8866 - loss: 1.9082
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 1.8312 - loss: 1.8525
# Epoch 12/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.2500 - categorical_crossentropy: 1.7924 - loss: 1.8136
# Epoch 13/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.2500 - categorical_crossentropy: 1.7542 - loss: 1.7752
# Epoch 14/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.2500 - categorical_crossentropy: 1.7254 - loss: 1.7461
# Epoch 15/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.2500 - categorical_crossentropy: 1.7006 - loss: 1.7211
# Epoch 16/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - categorical_accuracy: 0.2500 - categorical_crossentropy: 1.6779 - loss: 1.6982
# Epoch 17/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.1667 - categorical_crossentropy: 1.6560 - loss: 1.6761
# Epoch 18/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.2500 - categorical_crossentropy: 1.6353 - loss: 1.6552
# Epoch 19/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.2500 - categorical_crossentropy: 1.6153 - loss: 1.6350
# Epoch 20/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.2500 - categorical_crossentropy: 1.5961 - loss: 1.6156
# Epoch 21/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.2500 - categorical_crossentropy: 1.5773 - loss: 1.5967
# Epoch 22/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.2500 - categorical_crossentropy: 1.5592 - loss: 1.5784
# Epoch 23/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.2500 - categorical_crossentropy: 1.5414 - loss: 1.5604
# Epoch 24/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.2500 - categorical_crossentropy: 1.5244 - loss: 1.5433
# Epoch 25/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.2500 - categorical_crossentropy: 1.5077 - loss: 1.5265
# Epoch 26/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 1.4913 - loss: 1.5099
# Epoch 27/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 1.4752 - loss: 1.4936
# Epoch 28/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.2500 - categorical_crossentropy: 1.4596 - loss: 1.4780
# Epoch 29/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.2500 - categorical_crossentropy: 1.4447 - loss: 1.4629
# Epoch 30/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 1.4300 - loss: 1.4481
# Epoch 31/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 1.4161 - loss: 1.4340
# Epoch 32/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 1.4018 - loss: 1.4196
# Epoch 33/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 1.3887 - loss: 1.4064
# Epoch 34/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 1.3756 - loss: 1.3932
# Epoch 35/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 1.3633 - loss: 1.3808
# Epoch 36/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 1.3506 - loss: 1.3680
# Epoch 37/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 1.3389 - loss: 1.3562
# Epoch 38/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 1.3272 - loss: 1.3444
# Epoch 39/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 1.3162 - loss: 1.3333
# Epoch 40/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 1.3057 - loss: 1.3227
# Epoch 41/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 1.2953 - loss: 1.3122
# Epoch 42/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 1.2852 - loss: 1.3020
# Epoch 43/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 1.2756 - loss: 1.2923
# Epoch 44/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 1.2664 - loss: 1.2831
# Epoch 45/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 1.2576 - loss: 1.2741
# Epoch 46/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 1.2489 - loss: 1.2654
# Epoch 47/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 1.2409 - loss: 1.2574
# Epoch 48/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 1.2327 - loss: 1.2491
# Epoch 49/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 1.2251 - loss: 1.2414
# Epoch 50/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 1.2178 - loss: 1.2341
# Epoch 51/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 1.2108 - loss: 1.2270
# Epoch 52/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.3333 - categorical_crossentropy: 1.2041 - loss: 1.2202
# Epoch 53/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.1977 - loss: 1.2138
# Epoch 54/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.1915 - loss: 1.2075
# Epoch 55/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.1856 - loss: 1.2015
# Epoch 56/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.1799 - loss: 1.1959
# Epoch 57/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.1746 - loss: 1.1905
# Epoch 58/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.1694 - loss: 1.1853
# Epoch 59/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.1645 - loss: 1.1803
# Epoch 60/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.1598 - loss: 1.1755
# Epoch 61/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.1552 - loss: 1.1709
# Epoch 62/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.1508 - loss: 1.1665
# Epoch 63/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.1467 - loss: 1.1624
# Epoch 64/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.1428 - loss: 1.1583
# Epoch 65/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.1390 - loss: 1.1545
# Epoch 66/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.1354 - loss: 1.1509
# Epoch 67/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.1317 - loss: 1.1472
# Epoch 68/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.1285 - loss: 1.1439
# Epoch 69/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.1252 - loss: 1.1407
# Epoch 70/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.1221 - loss: 1.1375
# Epoch 71/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.1192 - loss: 1.1346
# Epoch 72/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.1164 - loss: 1.1317
# Epoch 73/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.1138 - loss: 1.1292
# Epoch 74/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.1111 - loss: 1.1264
# Epoch 75/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.1083 - loss: 1.1236
# Epoch 76/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.1056 - loss: 1.1209
# Epoch 77/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.1031 - loss: 1.1184
# Epoch 78/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.1005 - loss: 1.1157
# Epoch 79/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.0983 - loss: 1.1134
# Epoch 80/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.0959 - loss: 1.1111
# Epoch 81/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.0936 - loss: 1.1087
# Epoch 82/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.0915 - loss: 1.1066
# Epoch 83/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.0891 - loss: 1.1043
# Epoch 84/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.0870 - loss: 1.1022
# Epoch 85/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.0849 - loss: 1.1000
# Epoch 86/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.0827 - loss: 1.0977
# Epoch 87/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.0805 - loss: 1.0955
# Epoch 88/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.0783 - loss: 1.0933
# Epoch 89/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.0762 - loss: 1.0912
# Epoch 90/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.0742 - loss: 1.0892
# Epoch 91/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.0719 - loss: 1.0870
# Epoch 92/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.0692 - loss: 1.0842
# Epoch 93/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.0665 - loss: 1.0815
# Epoch 94/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.0638 - loss: 1.0788
# Epoch 95/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.0612 - loss: 1.0761
# Epoch 96/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.0583 - loss: 1.0733
# Epoch 97/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.4167 - categorical_crossentropy: 1.0554 - loss: 1.0704
# Epoch 98/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5000 - categorical_crossentropy: 1.0525 - loss: 1.0675
# Epoch 99/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5000 - categorical_crossentropy: 1.0499 - loss: 1.0648
# Epoch 100/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5000 - categorical_crossentropy: 1.0473 - loss: 1.0623
# Epoch 101/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5000 - categorical_crossentropy: 1.0448 - loss: 1.0598
# Epoch 102/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5000 - categorical_crossentropy: 1.0422 - loss: 1.0571
# Epoch 103/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5000 - categorical_crossentropy: 1.0396 - loss: 1.0545
# Epoch 104/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5000 - categorical_crossentropy: 1.0369 - loss: 1.0518
# Epoch 105/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5000 - categorical_crossentropy: 1.0342 - loss: 1.0491
# Epoch 106/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5000 - categorical_crossentropy: 1.0315 - loss: 1.0464
# Epoch 107/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.5000 - categorical_crossentropy: 1.0288 - loss: 1.0437
# Epoch 108/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5000 - categorical_crossentropy: 1.0261 - loss: 1.0410
# Epoch 109/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5000 - categorical_crossentropy: 1.0234 - loss: 1.0383
# Epoch 110/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5000 - categorical_crossentropy: 1.0207 - loss: 1.0356
# Epoch 111/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5000 - categorical_crossentropy: 1.0179 - loss: 1.0329
# Epoch 112/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5000 - categorical_crossentropy: 1.0151 - loss: 1.0300
# Epoch 113/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5000 - categorical_crossentropy: 1.0122 - loss: 1.0271
# Epoch 114/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5000 - categorical_crossentropy: 1.0093 - loss: 1.0242
# Epoch 115/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 1.0063 - loss: 1.0212
# Epoch 116/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 1.0033 - loss: 1.0182
# Epoch 117/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 1.0002 - loss: 1.0151
# Epoch 118/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 0.9970 - loss: 1.0119
# Epoch 119/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 0.9938 - loss: 1.0087
# Epoch 120/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 0.9904 - loss: 1.0054
# Epoch 121/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5000 - categorical_crossentropy: 0.9870 - loss: 1.0020
# Epoch 122/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5000 - categorical_crossentropy: 0.9835 - loss: 0.9985
# Epoch 123/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5000 - categorical_crossentropy: 0.9800 - loss: 0.9950
# Epoch 124/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5000 - categorical_crossentropy: 0.9765 - loss: 0.9914
# Epoch 125/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5000 - categorical_crossentropy: 0.9728 - loss: 0.9877
# Epoch 126/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5000 - categorical_crossentropy: 0.9692 - loss: 0.9842
# Epoch 127/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 0.9658 - loss: 0.9808
# Epoch 128/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 0.9625 - loss: 0.9775
# Epoch 129/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 0.9590 - loss: 0.9740
# Epoch 130/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 0.9555 - loss: 0.9706
# Epoch 131/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 0.9519 - loss: 0.9670
# Epoch 132/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 0.9484 - loss: 0.9635
# Epoch 133/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 0.9446 - loss: 0.9597
# Epoch 134/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 0.9406 - loss: 0.9557
# Epoch 135/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.9355 - loss: 0.9506
# Epoch 136/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.9305 - loss: 0.9457
# Epoch 137/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 0.9261 - loss: 0.9412
# Epoch 138/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 0.9217 - loss: 0.9368
# Epoch 139/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 0.9173 - loss: 0.9324
# Epoch 140/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 0.9131 - loss: 0.9283
# Epoch 141/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 0.9093 - loss: 0.9245
# Epoch 142/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 0.9061 - loss: 0.9213
# Epoch 143/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 0.9027 - loss: 0.9180
# Epoch 144/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 0.8995 - loss: 0.9147
# Epoch 145/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 0.8964 - loss: 0.9116
# Epoch 146/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 0.8931 - loss: 0.9084
# Epoch 147/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 0.8898 - loss: 0.9051
# Epoch 148/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 0.8866 - loss: 0.9019
# Epoch 149/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 0.8834 - loss: 0.8988
# Epoch 150/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 0.8799 - loss: 0.8953
# Epoch 151/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 0.8774 - loss: 0.8928
# Epoch 152/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 0.8747 - loss: 0.8902
# Epoch 153/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 0.8718 - loss: 0.8872
# Epoch 154/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 0.8694 - loss: 0.8848
# Epoch 155/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5833 - categorical_crossentropy: 0.8668 - loss: 0.8823
# Epoch 156/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.8638 - loss: 0.8793
# Epoch 157/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.8616 - loss: 0.8771
# Epoch 158/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.8590 - loss: 0.8745
# Epoch 159/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.8560 - loss: 0.8716
# Epoch 160/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.8538 - loss: 0.8694
# Epoch 161/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.8513 - loss: 0.8669
# Epoch 162/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.8484 - loss: 0.8640
# Epoch 163/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.8461 - loss: 0.8618
# Epoch 164/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.8437 - loss: 0.8594
# Epoch 165/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.8409 - loss: 0.8566
# Epoch 166/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.8383 - loss: 0.8541
# Epoch 167/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.8363 - loss: 0.8520
# Epoch 168/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.8335 - loss: 0.8493
# Epoch 169/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.8310 - loss: 0.8468
# Epoch 170/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.8285 - loss: 0.8443
# Epoch 171/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.8263 - loss: 0.8422
# Epoch 172/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.8237 - loss: 0.8396
# Epoch 173/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.8214 - loss: 0.8373
# Epoch 174/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.8189 - loss: 0.8349
# Epoch 175/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.8163 - loss: 0.8323
# Epoch 176/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.7500 - categorical_crossentropy: 0.8143 - loss: 0.8303
# Epoch 177/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.7500 - categorical_crossentropy: 0.8112 - loss: 0.8272
# Epoch 178/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.7500 - categorical_crossentropy: 0.8082 - loss: 0.8242
# Epoch 179/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.7500 - categorical_crossentropy: 0.8054 - loss: 0.8215
# Epoch 180/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.7500 - categorical_crossentropy: 0.8020 - loss: 0.8181
# Epoch 181/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.7500 - categorical_crossentropy: 0.7985 - loss: 0.8146
# Epoch 182/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.7500 - categorical_crossentropy: 0.7953 - loss: 0.8114
# Epoch 183/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.7500 - categorical_crossentropy: 0.7917 - loss: 0.8079
# Epoch 184/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.7500 - categorical_crossentropy: 0.7889 - loss: 0.8051
# Epoch 185/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.7500 - categorical_crossentropy: 0.7861 - loss: 0.8023
# Epoch 186/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.7500 - categorical_crossentropy: 0.7825 - loss: 0.7988
# Epoch 187/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.7500 - categorical_crossentropy: 0.7794 - loss: 0.7957
# Epoch 188/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.7500 - categorical_crossentropy: 0.7763 - loss: 0.7927
# Epoch 189/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.7500 - categorical_crossentropy: 0.7737 - loss: 0.7901
# Epoch 190/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.7500 - categorical_crossentropy: 0.7706 - loss: 0.7870
# Epoch 191/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.7500 - categorical_crossentropy: 0.7675 - loss: 0.7839
# Epoch 192/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.7500 - categorical_crossentropy: 0.7644 - loss: 0.7808
# Epoch 193/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.7500 - categorical_crossentropy: 0.7625 - loss: 0.7789
# Epoch 194/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.7500 - categorical_crossentropy: 0.7594 - loss: 0.7759
# Epoch 195/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.7500 - categorical_crossentropy: 0.7563 - loss: 0.7728
# Epoch 196/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.7500 - categorical_crossentropy: 0.7538 - loss: 0.7704
# Epoch 197/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.7500 - categorical_crossentropy: 0.7511 - loss: 0.7676
# Epoch 198/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.7500 - categorical_crossentropy: 0.7483 - loss: 0.7649
# Epoch 199/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.7500 - categorical_crossentropy: 0.7461 - loss: 0.7628
# Epoch 200/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.7500 - categorical_crossentropy: 0.7434 - loss: 0.7601
# LearningShapelets(max_iter=200, n_shapelets_per_size={12: 3}, verbose=1,
#                   weight_regularizer=0.01)

# %%
from sklearn.metrics import accuracy_score
predicted_labels = shp_clf.predict(X)
print("Correct classification rate:", accuracy_score(y, predicted_labels))
predicted_locations = shp_clf.locate(X)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Correct classification rate: 0.75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
ts_id = 0
plt.figure()
n_shapelets = sum(shapelet_sizes.values())
plt.title(f"""Example locations of shapelet matches ({n_shapelets} shapelets extracted)""")

plt.plot(X[ts_id].ravel())
for idx_shp, shp in enumerate(shp_clf.shapelets_):
    t0 = predicted_locations[ts_id, idx_shp]
    plt.plot(np.arange(t0, t0 + len(shp)), shp, linewidth=2)

# %% [markdown]
# ### Another way of extracting shaplets
#
# The Shapelet Transform algorithm extracts the most discriminative shapelets from a data set of time series. A shapelet is defined as a subset of consecutive points from a time series. Two criteria are made available: mutual information and F-scores.

# %%
from pyts.transformation import ShapeletTransform
st = ShapeletTransform(n_shapelets=5, window_sizes=[8])
st.fit(X, y)
# Out:
# ShapeletTransform(n_shapelets=5, window_sizes=[8])

# %%
len(st.shapelets_)
# Out:
# 5

# %%
st.shapelets_
# Out:
# array([[2.98646757, 3.37317756, 3.56491409, 1.51560696, 2.71553641,
#         3.37816335, 1.11274083, 3.4952731 ],
#        [2.38649756, 3.14754881, 2.43499739, 2.68289928, 2.25221836,
#         1.30229917, 3.57582743, 2.30220944],
#        [3.86768091, 3.44254948, 1.97362051, 4.03209882, 4.69276688,
#         2.65224013, 1.44202827, 2.40616013],
#        [1.98968297, 4.36556417, 4.12494848, 1.97593873, 1.89793117,
#         1.98066962, 1.99844116, 3.38858832],
#        [5.26993205, 4.98310642, 1.93153851, 2.67752343, 3.55562448,
#         2.71529886, 0.98846153, 2.14169181]])

# %%
for s in st.shapelets_:
    plt.plot(s)

plt.show()

# %% [markdown]
# The indices for the corresponding shapelets in the training set. The first column consists of the indices of the samples. The second column consists of the starting indices (included) of the shapelets. The third column consists of the ending indices (excluded) of the shapelets.

# %%
st.indices_
# Out:
# array([[ 2, 56, 64],
#        [ 6, 55, 63],
#        [ 5, 60, 68],
#        [ 2, 65, 73],
#        [11, 66, 74]])

# %%
st.scores_
# Out:
# array([0.72282047, 0.73922258, 0.76154401, 0.77463925, 0.84408369])

# %% [markdown]
# ### Shaplet + classification

# %%
from pyts.classification import LearningShapelets
shp_clf = LearningShapelets(random_state=42, tol=0.01)

# %%
shp_clf.fit(X, y)
# Out:
# LearningShapelets(random_state=42, tol=0.01)

# %%
accuracy = shp_clf.score(X , y)
accuracy
# Out:
# 1.0

# %%
shp_clf.predict(X)
# Out:
# array([2, 0, 1, 2, 0, 0, 1, 0, 2, 1, 1, 2])

# %%
# Select three shapelets
sel_shapelets = np.asarray([shp_clf.shapelets_[0, 0], 
                        shp_clf.shapelets_[0, 1], 
                        shp_clf.shapelets_[0, 2]])

# %%
plt.plot(sel_shapelets[0])
plt.plot(sel_shapelets[1])
plt.plot(sel_shapelets[2])

plt.show()
